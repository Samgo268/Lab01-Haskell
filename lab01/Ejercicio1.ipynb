-- %%
[1,2,3] ++ [4,5]
-- Out:
-- [1,2,3,4,5]

-- %%
 :t True
 :t "Hola mundo"
 :t [1,2,3]
-- Out:
-- True :: Bool
-- "Hola mundo" :: String
-- [1,2,3] :: forall {a}. Num a => [a]

-- %%
doble :: Int -> Int
doble x = x * 2
esMayorEdad :: Int -> Bool
esMayorEdad c = c >= 18
areaCirculo :: Float -> Float
areaCirculo n= pi (n*n)
x =  2
c = 31
n = 4.1
esMayorEdad c
-- Out:
-- True
