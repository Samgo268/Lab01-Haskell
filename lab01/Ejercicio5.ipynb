-- %%
f = (\x -> x+1)
map f [2, 3, 3]
-- Out:
-- Line 1: Redundant lambda
-- Found:
-- f = (\ x -> x + 1)
-- Why not:
-- f x = x + 1Line 1: Avoid lambda using `infix`
-- Found:
-- (\ x -> x + 1)
-- Why not:
-- (+ 1)Line 1: Redundant bracket
-- Found:
-- (\ x -> x + 1)
-- Why not:
-- \ x -> x + 1
-- [3,4,4]

-- %%
filter  (\x -> x `mod` 2 == 0) [2, 3, 4, 5]
-- Out:
-- Line 2: Use even
-- Found:
-- x `mod` 2 == 0
-- Why not:
-- even x
-- [2,4]

-- %%
(\(a,b) -> )
